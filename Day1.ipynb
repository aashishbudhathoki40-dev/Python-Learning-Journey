# %% [markdown]
# ### Output function

# %%
print("hello")
# Out:
# hello

# %%
2+2
# Out:
# 4

# %%
a=10

# %%
a
# Out:
# 10

# %%
a=11

# %%
a=9

# %%
a
# Out:
# 9

# %% [markdown]
# ##### If we are giving different value to a same character then that is over-written by the latest value that was assigned to the character.

# %%
print(1,2,3)
# Out:
# 1 2 3

# %%
print("my name is", "Aashish")
# Out:
# my name is Aashish

# %%
print("                 ",1)
# Out:
#                   1

# %% [markdown]
# ##### When we have space within the double quote than that also acts as a character that is printed after the statement is executed.

# %% [markdown]
# ##### Python is a case-sensitive language.

# %% [markdown]
# ##### in print statement we can only write variable name without quote otherwise we need to use double quote.

# %% [markdown]
# ### Rules for namin a variable
# - can start with capital or small alphabet
# - cannot start with number but not in the begining
# - only underscore to be allwed to be used as the symbol
# - dont use predefined words as variable name
# - snake case and camel case is allowed but kabab case is not allowed

# %%
a=11

# %%
b=45

# %%
print("the sum of",a,"and",b,"is",a+b)
# Out:
# the sum of 11 and 45 is 56

# %% [markdown]
# ### Data type and basic arithmetic operators
#
#     str     → Text              → "hello"
#     int     → Whole number      → 25
#     float   → Decimal           → 3.14
#     complex → Math (advanced)   → 2+3j
#     bool    → True / False      → True
#     None    → Empty value       → None
#
#
#     +   → Add
#     -   → Subtract
#     *   → Multiply
#     /   → Divide (gives decimal)
#     //  → Divide (whole number only)
#     %   → Remainder
#     **  → Power

# %% [markdown]
# ### F-String Formatting in Python

# %%
name = "Rahul"
age = 20
print(f"My name is {name} and I am {age} years old")
# Out:
# My name is Rahul and I am 20 years old
