# %% [markdown]
# ### Dictionaries

# %%
user = {"name": "Alice", "age": 25, "role": "Admin"}

# %%
print(user)
# Out:
# {'name': 'Alice', 'age': 25, 'role': 'Admin'}

# %%
print(type(user))
# Out:
# <class 'dict'>

# %%
print(user["name"])
# Out:
# Alice

# %%
print(len(user))
# Out:
# 3

# %%
print(user.keys())
# Out:
# dict_keys(['name', 'age', 'role'])

# %%
print(user.values())
# Out:
# dict_values(['Alice', 25, 'Admin'])

# %%
print(user.get("ages","This is not found in dictionary"))
# Out:
# This is not found in dictionary

# %%
data= user.get("age")
if data is None:
    print('data not found')
else:
    age=data+1

# %%
print("message...",age)
# Out:
# message... 26

# %%
user['role']="user"

# %%
print(user)
# Out:
# {'name': 'Alice', 'age': 25, 'role': 'user'}

# %%
user['number']=12345

# %%
print(user)
# Out:
# {'name': 'Alice', 'age': 25, 'role': 'user', 'number': 12345}

# %%
user.update({"name":"Aashish"})

# %%
print(user)
# Out:
# {'name': 'Aashish', 'age': 25, 'role': 'user', 'number': 12345}

# %%
user_info = {
    "name": "suman",
    "phone": [
        {
            "name": "Jio",
            "no": "985678"
        },
        {
            "name": "Ncell",
            "no": "980"
        }
    ]
}

# %%
print(f"Phone Number {user_info['phone'][0]['name']} of {user_info['name']}: {user_info['phone'][0]['no']}")
# Out:
# Phone Number Jio of suman: 985678
